# %% [markdown]
# # Name - Parikshit Sahu
# ## Code alpha internship task 3
# ## Music generation with AI

# %%
import music21
import numpy as np

# Function to parse MIDI files and extract note sequences
def get_notes(midi_files):
    notes = []
    for file in midi_files:
        midi = music21.converter.parse(file)
        notes_to_parse = None
        parts = music21.instrument.partitionByInstrument(midi)
        
        if parts:  # if the file has instrument parts
            notes_to_parse = parts.parts[0].recurse()
        else:
            notes_to_parse = midi.flat.notes
        
        for element in notes_to_parse:
            if isinstance(element, music21.note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, music21.chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))
    
    return notes

# %%
from sklearn.preprocessing import LabelEncoder

def prepare_sequences(notes, sequence_length):
    # Get all unique pitches
    encoder = LabelEncoder()
    encoded_notes = encoder.fit_transform(notes)
    n_vocab = len(set(encoded_notes))

    # Create sequences for the LSTM
    network_input = []
    network_output = []

    for i in range(0, len(encoded_notes) - sequence_length, 1):
        seq_in = encoded_notes[i:i + sequence_length]
        seq_out = encoded_notes[i + sequence_length]
        network_input.append(seq_in)
        network_output.append(seq_out)

    # Reshape and normalize input data
    n_patterns = len(network_input)
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    network_input = network_input / float(n_vocab)

    # One-hot encode the output
    network_output = np.eye(n_vocab)[network_output]

    return network_input, network_output, encoder

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

def build_model(network_input, n_vocab):
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(network_input.shape[1], network_input.shape[2]),
        return_sequences=True
    ))
    model.add(Dropout(0.3))
    model.add(LSTM(512, return_sequences=False))
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
def train_model(model, network_input, network_output, epochs=100, batch_size=64):
    model.fit(network_input, network_output, epochs=epochs, batch_size=batch_size)

# %%
def generate_notes(model, network_input, encoder, n_vocab, num_notes=500):
    # Choose a random starting point
    start = np.random.randint(0, len(network_input) - 1)
    pattern = network_input[start]

    prediction_output = []

    # Generate notes
    for note_index in range(num_notes):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = np.argmax(prediction)
        result = encoder.inverse_transform([index])[0]
        prediction_output.append(result)

        # Add the predicted note to the input sequence
        pattern = np.append(pattern, index)
        pattern = pattern[1:]

    return prediction_output

# %%
from music21 import instrument, note, chord, stream

def create_midi(prediction_output, filename='output.mid'):
    offset = 0
    output_notes = []

    for pattern in prediction_output:
        # If the pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        else:
            # If the pattern is a note
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # Increase the offset to avoid stacking
        offset += 0.5

    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp=filename)

# %%
midi_files = [r'C:\Users\sahup\midi_files\101627.mid', r'C:\Users\sahup\midi_files\82625.mid',r'C:\Users\sahup\midi_files\112561.mid']  # List of MIDI files
notes = get_notes(midi_files)

sequence_length = 100
network_input, network_output, encoder = prepare_sequences(notes, sequence_length)
n_vocab = len(encoder.classes_)

model = build_model(network_input, n_vocab)
train_model(model, network_input, network_output, epochs=200, batch_size=128)

generated_notes = generate_notes(model, network_input, encoder, n_vocab, num_notes=500)
create_midi(generated_notes, 'generated_music.mid')
# Out:
# C:\Users\sahup\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 3.1518
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 3.3021
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 2.6242
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 2.7359
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.5942
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 2.4454
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.4157
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.4945
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.4164
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3714
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.3955
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.3740
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3647
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.4012
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3759
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3768
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3315
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3358
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3446
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3886
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3519
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3135
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3343
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3381
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3056
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3812
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3685
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3433
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3537
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3440
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.3385
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2799
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3069
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3779
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2905
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3314
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2661
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.2923
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2762
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.3000
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2303
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2352
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2138
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.2299
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.1762
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.1820
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.1360
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.0543
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.0318
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.9979
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.9547
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.0714
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.4960
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.1670
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.0386
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 2.0651
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.9693
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.9879
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.8749
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.9702
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.7243
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.8378
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.7334
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.6701
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.6085
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.6156
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 1.5217
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.5087
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4827
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4711
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4579
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.4386
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.4923
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.8165
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.6221
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.5336
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.4984
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4991
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4808
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.4219
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.3635
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.3944
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.3022
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2494
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.3039
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2355
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.2222
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.2983
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.2243
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.2532
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.1998
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2279
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2016
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2175
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.1732
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.2531
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.2386
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.1626
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.1162
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.0546
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.0268
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.0443
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.0754
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.0416
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 1.0455
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9934
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.1125
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9734
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 1.0689
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.0624
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.0424
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 1.0553
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.0751
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9975
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9634
# Epoch 116/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9576
# Epoch 117/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9690
# Epoch 118/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9506
# Epoch 119/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9086
# Epoch 120/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9112
# Epoch 121/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9333
# Epoch 122/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9693
# Epoch 123/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9137
# Epoch 124/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9765
# Epoch 125/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.8684
# Epoch 126/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.9046
# Epoch 127/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8826
# Epoch 128/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9158
# Epoch 129/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.9085
# Epoch 130/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.8267
# Epoch 131/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7975
# Epoch 132/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7947
# Epoch 133/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7704
# Epoch 134/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7589
# Epoch 135/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7724
# Epoch 136/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7855
# Epoch 137/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8607
# Epoch 138/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9924
# Epoch 139/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.8494
# Epoch 140/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.8277
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7975
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9062
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9771
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 1.0093
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.9009
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8767
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8064
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.8075
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7984
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.7672
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7892
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.8031
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - loss: 0.8550
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.8357
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7411
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7720
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7713
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7449
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7345
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7954
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8479
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7296
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7410
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7892
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7717
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7144
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7573
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.7198
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6839
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6819
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6706
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6511
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6633
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6746
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6187
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6060
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6460
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.5862
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6153
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.5829
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.6211
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6377
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6274
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6010
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6498
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.8448
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.7245
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6516
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6710
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6610
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.6404
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6742
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.6732
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6393
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6155
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.5761
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.5873
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.5755
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.6021
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - loss: 0.5615
